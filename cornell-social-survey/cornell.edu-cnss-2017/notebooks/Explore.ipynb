# %%
import matplotlib.pyplot as plt 
import metapack as mp
import pandas as pd
import numpy as np
import seaborn as sns
sns.set(color_codes=True)
# %matplotlib inline

# %%
pkg = mp.jupyter.open_package()
pkg
# Out:
# <h2>Cornell National Social Survey (CNSS), 2017</h2>
# <p><p><em>Cornell National Social Survey is a random-sample survey of adults aged 18 and over. In 2017, participants were asked their opinions on a range of topics.</em></p>
# <p><small>cornell.edu-cnss-2017-1 from metapack+file:///Users/eric/proj/virt-proj/data-project/sdrdl-data-projects/cornell-social-survey/cornell.edu-cnss-2017/_packages/cornell.edu-cnss-2017-1/metadata.csv</small></p></p>
# <p>To use this package, you will have to download the research file manually,
# placing the file in the data directory. Cornell requires you to accept terms
# and conditions before downloading the file, so we can't redistribute it.</p>
# <p>I used Stat Transfer to convert the SPSS file to Stata, but there is one
# variable, KRq1, "Number of Dogs Owned", that StatTransfer converts with
# duplicate labels.</p>
# <h3>Documentation</h3>
# <ul>
# <li><strong><a href="https://cisermgmt.cornell.edu/go/PHPs/rsch_downloadPUB.php?COMPDL=pub/034/cnss2017_Codebook.pdf.zip&amp;IDTITLE=2805&amp;PERMLEVEL=0">Codebook</a></strong> None</li>
# <li><strong><a href="https://cisermgmt.cornell.edu/go/PHPs/rsch_downloadPUB.php?COMPDL=pub/034/Results_and_Citation_Guidelines.pdf.zip&amp;IDTITLE=2805&amp;PERMLEVEL=0">Results and Citation Guidelines</a></strong> None</li>
# </ul>
# <h3>Contacts</h3>
# <p><strong>Wrangler:</strong> <a href="mailto:eric@civicknowledge.com">Eric Busboom</a> <a href="http://civicknowledge.com">Civic Knowledge</a></p>
# <h3>Resources</h3>
# <p><ol>
# <li><p><a target="_blank" href="file:///Users/eric/proj/virt-proj/data-project/sdrdl-data-projects/cornell-social-survey/cornell.edu-cnss-2017/_packages/cornell.edu-cnss-2017-1/data/cnss_2017.csv"><strong>cnss_2017</strong></a> CNSS 2017, with categorical values</p></li></p>
# </ol>
#
# <h3>References</h3>
# <p><ol>
# <li><p><a target="_blank" href="file:///Users/eric/proj/virt-proj/data-project/sdrdl-data-projects/cornell-social-survey/cornell.edu-cnss-2017/_packages/cornell.edu-cnss-2017-1/data/cnss2017.dta"><strong>cnss_2017</strong></a> Cornell National Social Survey 2017, in converted Stata forma</p></li></p>
# </ol>

# %%
pkg.resource('cnss_2017')
# Out:
# <Resource: metadata.csv 34:1 root.datafile data/cnss_2017.csv ['cnss_2017', 'CNSS 2017, with categorical values', '']>

# %%
df = pkg.resource('cnss_2017').read_csv()

# %%
pd.pivot_table(df, index='party', columns='gender', values='caseid', aggfunc=len, margins=True)
# Out:
# gender                                 Female  Male  All
# party
# Independent (close to Neither)            110   135  245
# Independent, close to Democrat             56    39   95
# Independent, close to Republican           44    52   96
# Not very strong Democrat                   60    55  115
# Not very strong Republican                 45    50   95
# Other party affiliation (specify ...)      17    26   43
# Strong Democrat                           104    71  175
# Strong Republican                          62    70  132
# All                                       498   498  996

# %%
pd.pivot_table(df, index='riq1', columns='gender', values='caseid', aggfunc=len, margins=True)
# Out:
# gender            Female  Male  All
# riq1
# All of the above     201   192  393
# Bacteria             266   247  513
# Fungi                  7     8   15
# Viruses               22    36   58
# All                  496   483  979

# %%
pd.pivot_table(df, index='party', columns='ideo', values='caseid', aggfunc=len, margins=True)
# Out:
# ideo                                   Conservative  Extremely conservative  \
# party
# Independent (close to Neither)                 26.0                     5.0
# Independent, close to Democrat                  2.0                     NaN
# Independent, close to Republican               29.0                     6.0
# Not very strong Democrat                        8.0                     NaN
# Not very strong Republican                     31.0                     6.0
# Other party affiliation (specify ...)           2.0                     2.0
# Strong Democrat                                 8.0                     3.0
# Strong Republican                              65.0                    25.0
# All                                           171.0                    47.0
#
# ideo                                   Extremely liberal  Liberal  \
# party
# Independent (close to Neither)                       3.0     34.0
# Independent, close to Democrat                      14.0     25.0
# Independent, close to Republican                     NaN      1.0
# Not very strong Democrat                             9.0     30.0
# Not very strong Republican                           NaN      3.0
# Other party affiliation (specify ...)                4.0      4.0
# Strong Democrat                                     38.0     62.0
# Strong Republican                                    3.0      3.0
# All                                                 71.0    162.0
#
# ideo                                   Moderate or middle of the road  \
# party
# Independent (close to Neither)                                  132.0
# Independent, close to Democrat                                   36.0
# Independent, close to Republican                                 34.0
# Not very strong Democrat                                         43.0
# Not very strong Republican                                       34.0
# Other party affiliation (specify ...)                            20.0
# Strong Democrat                                                  43.0
# Strong Republican                                                21.0
# All                                                             363.0
#
# ideo                                   Slightly conservative  \
# party
# Independent (close to Neither)                          25.0
# Independent, close to Democrat                           5.0
# Independent, close to Republican                        25.0
# Not very strong Democrat                                 9.0
# Not very strong Republican                              20.0
# Other party affiliation (specify ...)                    6.0
# Strong Democrat                                          2.0
# Strong Republican                                       15.0
# All                                                    107.0
#
# ideo                                   Slightly liberal  All
# party
# Independent (close to Neither)                     18.0  243
# Independent, close to Democrat                     13.0   95
# Independent, close to Republican                    1.0   96
# Not very strong Democrat                           16.0  115
# Not very strong Republican                          1.0   95
# Other party affiliation (specify ...)               2.0   40
# Strong Democrat                                    17.0  173
# Strong Republican                                   NaN  132
# All                                                68.0  989

# %%
pd.pivot_table(df, index='party', columns='idq4', values='caseid', aggfunc=len, margins=True)
# Out:
# idq4                                   Agree  Disagree  \
# party
# Independent (close to Neither)          71.0      37.0
# Independent, close to Democrat          26.0       8.0
# Independent, close to Republican        27.0      22.0
# Not very strong Democrat                44.0      15.0
# Not very strong Republican              27.0      23.0
# Other party affiliation (specify ...)   14.0       4.0
# Strong Democrat                         57.0      20.0
# Strong Republican                       22.0      36.0
# All                                    288.0     165.0
#
# idq4                                   Neither agree or disagree  \
# party
# Independent (close to Neither)                              39.0
# Independent, close to Democrat                              14.0
# Independent, close to Republican                            15.0
# Not very strong Democrat                                    23.0
# Not very strong Republican                                  24.0
# Other party affiliation (specify ...)                        5.0
# Strong Democrat                                             27.0
# Strong Republican                                           28.0
# All                                                        175.0
#
# idq4                                   Strongly agree  Strongly disagree  All
# party
# Independent (close to Neither)                   89.0                9.0  245
# Independent, close to Democrat                   47.0                NaN   95
# Independent, close to Republican                 24.0                8.0   96
# Not very strong Democrat                         30.0                3.0  115
# Not very strong Republican                       15.0                6.0   95
# Other party affiliation (specify ...)            17.0                3.0   43
# Strong Democrat                                  66.0                5.0  175
# Strong Republican                                23.0               23.0  132
# All                                             311.0               57.0  996

# %%
pd.pivot_table(df, index='kwq1_b', columns='kwq1_a', values='caseid', aggfunc=len, margins=True)
# Out:
# kwq1_a   No  Yes  All
# kwq1_b
# No      570  149  719
# Yes     138  142  280
# All     708  291  999

# %%
df.groupby(['kwq1_a','kwq1_b']).age.count()
# Out:
# kwq1_a  kwq1_b
# No      No        570
#         Yes       138
# Yes     No        149
#         Yes       142
# Name: age, dtype: int64

# %%
pd.crosstab(df.kwq1_b, df.race_b, values='caseid', aggfunc=len, margins=True, normalize='all')
# Out:
# race_b        No       Yes       All
# kwq1_b
# No      0.629032  0.091734  0.720766
# Yes     0.225806  0.053427  0.279234
# All     0.854839  0.145161  1.000000

# %%
_1 = pd.crosstab(df.kwq1_b, df.race_b, values='caseid', aggfunc=len, normalize='all')

_1
# Out:
# race_b        No       Yes
# kwq1_b
# No      0.629032  0.091734
# Yes     0.225806  0.053427

# %%
pd.crosstab(df.kwq1_b, df.race_b, values='caseid', aggfunc=len, normalize='columns')
# Out:
# race_b        No       Yes
# kwq1_b
# No      0.735849  0.631944
# Yes     0.264151  0.368056

# %%
# "Minorities get government advantages" Vs Black

#  { k:k for k in list(df.idq5.unique()) } Make the mapping dict

df['min_advtg'] =  df.idq5.replace(
    {'Disagree': 'Disagree',
    'Strongly agree': 'Agree',
    'Strongly disagree': 'Disagree',
    'Agree': 'Agree',
    'Neither agree or disagree': np.nan,
    np.nan: np.nan})

df['race_b'] = df.race_b.replace({'Yes': 'Black', 'No': 'Not Black'})

pd.crosstab(df.min_advtg, df.race_b, values='caseid', aggfunc=len, normalize='columns')
# Out:
# race_b        Black  Not Black
# min_advtg
# Agree      0.578125   0.430029
# Disagree   0.421875   0.569971

# %%
# EBq2 "Worry about crime, neighborhood " Vs Black

#  { k:k for k in list(df.idq5.unique()) } Make the mapping dict

df['worry_crime_neighborhood'] =  df.ebq2.replace(
    {'Only a little': 'Less',
     'A fair amount': 'More',
     'Not at all': 'Less',
     'A great deal': 'More'})

df['race_b'] = df.race_b.replace({'Yes': 'Black', 'No': 'Not Black'})

pd.crosstab(df.worry_crime_neighborhood, df.race_b, values='caseid', aggfunc=len, normalize='columns')
# Out:
# race_b                       Black  Not Black
# worry_crime_neighborhood
# Less                      0.520833   0.724382
# More                      0.479167   0.275618

# %%
# kwq1_b "Experienced Domestic Violence " Vs Party

#  { k:k for k in list(df.idq5.unique()) } Make the mapping dict

df['party_agg'] =  df.party.replace(
    {'Independent (close to Neither)': 'Independent',
    'Not very strong Democrat': 'Democrat',
    'Independent, close to Republican': 'Independent',
    'Strong Republican': 'Republican',
    'Independent, close to Democrat': 'Independent',
    'Not very strong Republican': 'Republican',
    'Strong Democrat': 'Democrat',
    'Other party affiliation (specify ...)': np.nan,
    np.nan: np.nan}
)


pd.crosstab(df.kwq1_b, df.party_agg, values='caseid', aggfunc=len, normalize='columns')
# Out:
# party_agg  Democrat  Independent  Republican
# kwq1_b
# No         0.696552     0.705747    0.801762
# Yes        0.303448     0.294253    0.198238

# %%
# SKq5 "Feminism Good or Bad " Vs Party

df['feminism_good'] =  df.party.replace(
    {'Neutral': 'Neutral',
    'Strongly agree': 'Agree',
    'Disagree': 'Disagree',
    'Strongly disagree': 'Disagree',
    'Agree': 'Agree',
    np.nan: np.nan}
)

pd.crosstab(df.skq5, df.party_agg, values='caseid', aggfunc=len, normalize='columns')
# Out:
# {'Neutral': 'Neutral',
#  'Strongly agree': 'Strongly agree',
#  'Disagree': 'Disagree',
#  'Strongly disagree': 'Strongly disagree',
#  'Agree': 'Agree'}

# %%
from scipy.stats import pointbiserialr

# %%
_1 = pd.get_dummies(df[['skq1','skq2_a']])

pointbiserialr(_1.skq1_Yes, _1.skq2_a_Yes)
# Out:
# PointbiserialrResult(correlation=0.09969027556610287, pvalue=0.0015972627271983277)

# %%
_1.head()
# Out:
#    skq1_No  skq1_Yes  skq2_a_No  skq2_a_Yes
# 0        1         0          1           0
# 1        1         0          1           0
# 2        1         0          0           1
# 3        1         0          1           0
# 4        1         0          1           0

# %%
_1 = pd.get_dummies(df[['skq1','skq3']])
_1.corr()
# Out:
#                                            skq1_No  skq1_Yes   skq3_No  \
# skq1_No                                   1.000000 -1.000000  0.008431
# skq1_Yes                                 -1.000000  1.000000 -0.008431
# skq3_No                                   0.008431 -0.008431  1.000000
# skq3_Unfamiliar with the term alpha male  0.056115 -0.056115 -0.409994
# skq3_Yes                                 -0.041827  0.041827 -0.796235
#
#                                           skq3_Unfamiliar with the term alpha male  \
# skq1_No                                                                   0.056115
# skq1_Yes                                                                 -0.056115
# skq3_No                                                                  -0.409994
# skq3_Unfamiliar with the term alpha male                                  1.000000
# skq3_Yes                                                                 -0.173474
#
#                                           skq3_Yes
# skq1_No                                  -0.041827
# skq1_Yes                                  0.041827
# skq3_No                                  -0.796235
# skq3_Unfamiliar with the term alpha male -0.173474
# skq3_Yes                                  1.000000

# %%
df.ahq3.value_counts()
# Out:
# Strongly agree                450
# Somewhat agree                243
# Neither agree nor disagree    122
# Somewhat disagree             106
# Strongly disagree              78
# Name: ahq3, dtype: int64

# %%
df.kwq2.value_counts()
# Out:
# No- they haven't had an impact on my work.    241
# Yes                                           152
# Name: kwq2, dtype: int64

# %%
df.ebq1.value_counts()
# Out:
# Not at all                     377
# N/A - Not currently working    275
# Only a little                  202
# A fair amount                   88
# A great deal                    58
# Name: ebq1, dtype: int64

# %%
df.mjq1.value_counts()
# Out:
# Somewhat positive impact    261
# Neutral                     259
# Very positive impact        218
# Somewhat negative impact    165
# Very negative impact         94
# Name: mjq1, dtype: int64
