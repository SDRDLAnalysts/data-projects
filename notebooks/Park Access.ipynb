# %%
import seaborn as sns
import metapack as mp
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display 

# %matplotlib inline
sns.set_context('notebook')

# %%
import metapack as mp
pkg = mp.open_package('http://library.metatab.org/healthyplacesindex.org-healthy_places_index-san_diego-2.zip')

pkg
# Out:
# <h1>California Healthy Places Index</h1>
# <p><code>healthyplacesindex.org-healthy_places_index-san_diego-2</code> Last Update: 2018-09-14T17:08:44</p>
# <p><em>The HPI provides overall scores and more detailed data on specific policy action areas that shape health, like housing, transportation, education and more.</em></p>
# <p>The Healthy Places Index is a collection of indicators produced by the Public
# Health Alliance of Southern California from a wide variety of data sources to
# study social determinants of health. It offers index values for many topics --
# about 80 columns -- as well as a weighted aggreate index value, all at the
# tract level.</p>
# <p>This version of the HPI presents the original file with only one modification: the Tiger format Geoid for tracts has been converted to ACS format.  </p>
# <h2>Documentation Links</h2>
# <ul>
# ...

# %%
pkg.resource('hpi')
# Out:
# <Resource: metadata.csv 35:1 root.datafile data/hpi.csv ['hpi', 'Healthy Places Index master file', '', '', '']>

# %%
import metapack as mp
com_pkg = mp.open_package('http://library.metatab.org/sandiegodata.org-communities-2018-7.csv')
com_pkg
# Out:
# <h1>Community and City and Tract Boundaries in San Diego County</h1>
# <p><code>sandiegodata.org-communities-2018-7</code> Last Update: 2018-09-15T00:33:07</p>
# <p><em>Combines  geographic boundary files for communities, cities and tracts in San Diego County.</em></p>
# <p>This package combines three SANGIS datasets for communities and cities in San Diego county into a single file, in the <code>communities</code> resource, with Census tract definitions for San Diego count. The source files are: </p>
# <ul>
# <li>Municipal boundaries, of incorporated cities and the rest of the county</li>
# <li>Communities in unincorporated county areas</li>
# <li>Communities in San Diego. </li>
# <li>Census tract boundaries for 2016</li>
# </ul>
# <p>In addition to simply combining these four boundary files, the dataset also
# links tracts into the other three regions, in the <code>tracts_links</code> and
# <code>tracts_all_regions</code> datasets. Using these datasets, you can get all of the
# ...

# %%
hpi = pkg.resource('hpi').dataframe()
hpi.head()
# Out:
#                         geoid  pop2010  pct2010gq     city      zip  \
# 0  14000US6001400100000000000     2937        0.1  Oakland  94704.0
# 1  14000US6001400200000000000     1974        3.5  Oakland  94618.0
# 2  14000US6001400300000000000     4865        0.8  Oakland  94618.0
# 3  14000US6001400400000000000     3703        0.9  Oakland  94609.0
# 4  14000US6001400500000000000     3517        3.6  Oakland  94609.0
#
#    county_fips county_name   urbantype  hpi2score  hpi2_pctile_pos  \
# 0         6001     Alameda  urban_area   1.182028        99.114590
# 1         6001     Alameda  urban_area   1.325874        99.704863
# 2         6001     Alameda  urban_area   0.925666        95.932247
# 3         6001     Alameda  urban_area   1.117603        98.537149
# 4         6001     Alameda  urban_area   0.562799        83.318363
#
#       ...      leb_pctile  white_pct  black_pct  asian_pct  latino_pct  \
# 0     ...       96.663673  71.605789   4.824259  15.713301    4.031702
# ...

# %%
# Percentage of the population living within a half-mile of a park, beach, or open space greater than 1 acre
