# %%
import pandas as pd
import metapack as mp

# %%
itr = pd.read_sas('../data/adult_2017_sas/adult.xpt', iterator=True)

# %%
c = itr.columns[8]
c.label, c.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-0a3dc9816248> in <module>
#       1 c = itr.columns[8]
# ----> 2 c.label, c.name
#
# AttributeError: 'str' object has no attribute 'label'

# %%
itr.fields
# Out:
# [{'ntype': 'numeric',
#   'nhfun': 0,
#   'field_length': 8,
#   'nvar0': 1,
#   'name': b'AA5C',
#   'label': b'ENROLLED MEMBER IN RECOGNIZED TRIBE',
#   'nform': b'',
#   'nfl': 0,
#   'num_decimals': 0,
#   'nfj': 0,
#   'nfill': b'\x00\x00',
#   'niform': b'',
#   'nifl': 0,
#   'nifd': 0,
#   'npos': 0},
#  {'ntype': 'numeric',
#   'nhfun': 0,
#   'field_length': 8,
#   'nvar0': 2,
#   'name': b'AB1',
#   'label': b'GENERAL HEALTH CONDITION',
#   'nform': b'',
#   'nfl': 0,
#   'num_decimals': 0,
#   'nfj': 0,
#   'nfill': b'\x00\x00',
#   'niform': b'',
#   'nifl': 0,
#   'nifd': 0,
#   'npos': 8},
#  {'ntype': 'numeric',
#   'nhfun': 0,
#   'field_length': 8,
#   'nvar0': 3,
#   'name': b'AB17',
#   'label': b'DOCTOR EVER TOLD HAVE ASTHMA',
#   'nform': b'',
#   'nfl': 0,
#   'num_decimals': 0,
#   'nfj': 0,
#   'nfill': b'\x00\x00',
#   'niform': b'',
#   'nifl': 0,
#   'nifd': 0,
#   'npos': 16},
#  {'ntype': 'numeric',
#   'nhfun': 0,
#   'field_length': 8,
#   'nvar0': 4,
# ...

# %%
type(itr)
# Out:
# pandas.io.sas.sas_xport.XportReader
