# %%
import seaborn as sns
import metapack as mp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display 

# %matplotlib inline
sns.set_context('notebook')
mp.jupyter.init()

# %%
pkg = mp.jupyter.open_package()
#pkg = mp.jupyter.open_source_package()
pkg
# Out:
# <h1>StoryTent users and Checkins</h1>
# <p><code>tablecloth.io-storytent-201811-3</code> Last Update: 2018-12-17T19:10:08</p>
# <p><em>StoryTent data processed to break out a user table from checkins.</em></p>
# <h1></h1>
# <ul>
# <li>Convert dates for birthdates, from integers to ISO. </li>
# <li>Check for duplicate </li>
# <li>Break out into two files: <ul>
# <li>Checkin table, just checkin times, attatude information</li>
# <li>User table, just user information, from old system, or from Long checkin. </li>
# </ul>
# </li>
# </ul>
# <h2>Notes</h2>
# <ul>
# <li>Version 1: Initial Version</li>
# <li>Version 2: adds user table</li>
# <li>Version 3: Adds table for matches checkins/checkouts </li>
# </ul>
# <h2>Contacts</h2>
# <ul>
# <li><strong>Wrangler</strong> <a href="mailto:eric@civicknowledge.com">Eric Busboom</a>, <a href="http://civicknowledge.com">Civic Knowledge</a></li>
# </ul>
# <h2>Resources</h2>
# <ul>
# <li><strong> <a href="data/source.csv">source</a></strong>. Latest download</li>
# <li><strong> <a href="data/combined_source.csv">combined_source</a></strong>. Latest download plus older records</li>
# <li><strong> <a href="data/users.csv">users</a></strong>. Lightly processed user table records</li>
# <li><strong> <a href="data/user_table.csv">user_table</a></strong>. User table</li>
# <li><strong> <a href="data/checkins.csv">checkins</a></strong>. Checkin records, with user_table link</li>
# <li><strong> <a href="notebooks/CheckInTable.ipynb#ci_table">ci_table</a></strong>. Checkin Table</li>
# </ul>
# <h2>References</h2>
# <ul>
# <li><strong><a href="index:tablecloth.io-storytent-5#source_new_schema">orig_source</a></strong>. Original source</li>
# </ul>

# %%
source = pkg.resource('combined_source').read_csv()
source.head()
# Out:
#     id location first_name last_name   sex  grade             birthday  \
# 0  NaN  ElCajon      Aelen    Putrus  Girl    1.0  2011-04-13 00:00:00
# 1  NaN  ElCajon      Yemen    Putrus   Boy    4.0  2008-05-05 00:00:00
# 2  NaN  ElCajon     Regina    Alkass  Girl    1.0  2012-08-26 00:00:00
# 3  NaN  ElCajon   Abdallah     Saleh   Boy    1.0  2011-03-23 00:00:00
# 4  NaN  ElCajon      Sarah     Saleh  Girl    3.0  2009-04-27 00:00:00
#
#              feeling           start_date         submit_date network_id  \
# 0         heart eyes  2017-10-25 23:29:23 2017-10-25 23:29:23        NaN
# 1       smiling face  2017-10-25 23:30:37 2017-10-25 23:30:37        NaN
# 2         heart eyes  2017-10-25 23:32:42 2017-10-25 23:32:42        NaN
# 3  screaming in fear  2017-10-25 23:46:01 2017-10-25 23:46:01        NaN
# 4       smiling face  2017-10-25 23:47:51 2017-10-25 23:47:51        NaN
#
#       form clientid tablecloth_link qr_code_link
# 0  Checkin      NaN             NaN          NaN
# 1  Checkin      NaN             NaN          NaN
# 2  Checkin      NaN             NaN          NaN
# 3  Checkin      NaN             NaN          NaN
# 4  Checkin      NaN             NaN          NaN

# %%
ci = pkg.resource('checkins').read_csv()
ci.head()
# Out:
#    user_id   id location            feeling          start_date  \
# 0    901.0  NaN  ElCajon         heart eyes 2017-10-25 23:29:23
# 1    902.0  NaN  ElCajon       smiling face 2017-10-25 23:30:37
# 2     81.0  NaN  ElCajon         heart eyes 2017-10-25 23:32:42
# 3   1004.0  NaN  ElCajon  screaming in fear 2017-10-25 23:46:01
# 4   1009.0  NaN  ElCajon       smiling face 2017-10-25 23:47:51
#
#           submit_date network_id     form clientid tablecloth_link  \
# 0 2017-10-25 23:29:23        NaN  Checkin      NaN             NaN
# 1 2017-10-25 23:30:37        NaN  Checkin      NaN             NaN
# 2 2017-10-25 23:32:42        NaN  Checkin      NaN             NaN
# 3 2017-10-25 23:46:01        NaN  Checkin      NaN             NaN
# 4 2017-10-25 23:47:51        NaN  Checkin      NaN             NaN
#
#   qr_code_link
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
len(ci)
# Out:
# 8775
